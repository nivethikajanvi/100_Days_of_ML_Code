# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dphi-official/Datasets/master/kc_house_data/kc_house_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16613 entries, 0 to 16612
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          16613 non-null  float64
#  1   bedrooms       16613 non-null  int64
#  2   bathrooms      16613 non-null  float64
#  3   sqft_living    16613 non-null  int64
#  4   sqft_lot       16613 non-null  int64
#  5   floors         16613 non-null  float64
#  6   waterfront     16613 non-null  int64
#  7   view           16613 non-null  int64
#  8   condition      16613 non-null  int64
#  9   grade          16613 non-null  int64
#  10  sqft_above     16613 non-null  int64
#  11  sqft_basement  16613 non-null  int64
#  12  yr_built       16613 non-null  int64
#  13  yr_renovated   16613 non-null  int64
#  14  zipcode        16613 non-null  int64
#  15  lat            16613 non-null  float64
#  16  long           16613 non-null  float64
#  17  sqft_living15  16613 non-null  int64
#  18  sqft_lot15     16613 non-null  int64
# dtypes: float64(5), int64(14)
# memory usage: 2.4 MB

# %%
df
# Out:
#           price  bedrooms  bathrooms  ...     long  sqft_living15  sqft_lot15
# 0      221900.0         3       1.00  ... -122.257           1340        5650
# 1      538000.0         3       2.25  ... -122.319           1690        7639
# 2      180000.0         2       1.00  ... -122.233           2720        8062
# 3      604000.0         4       3.00  ... -122.393           1360        5000
# 4      510000.0         3       2.00  ... -122.045           1800        7503
# ...         ...       ...        ...  ...      ...            ...         ...
# 16608  245000.0         2       1.00  ... -122.295           1220        1740
# 16609  275000.0         4       2.00  ... -122.196           1450        8768
# 16610  270000.0         3       2.00  ... -122.368           1570        7227
# 16611  767250.0         4       3.00  ... -122.303           2170        4080
# 16612  229000.0         3       2.00  ... -122.338           1190        9900
#
# [16613 rows x 19 columns]

# %%
df.shape
# Out:
# (16613, 19)

# %%
df.describe()
# Out:
#               price      bedrooms  ...  sqft_living15     sqft_lot15
# count  1.661300e+04  16613.000000  ...   16613.000000   16613.000000
# mean   5.335161e+05      3.365918  ...    1974.793776   13287.334256
# std    3.665165e+05      0.937185  ...     673.022438   27456.421787
# min    7.500000e+04      0.000000  ...     399.000000     660.000000
# 25%    3.150000e+05      3.000000  ...    1490.000000    5421.000000
# 50%    4.470000e+05      3.000000  ...    1830.000000    7823.000000
# 75%    6.387000e+05      4.000000  ...    2330.000000   10327.000000
# max    7.700000e+06     33.000000  ...    6110.000000  871200.000000
#
# [8 rows x 19 columns]

# %%
df.isnull().sum()
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
del df['lat']

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  ...     long  sqft_living15  sqft_lot15
# 0  221900.0         3       1.00  ... -122.257           1340        5650
# 1  538000.0         3       2.25  ... -122.319           1690        7639
# 2  180000.0         2       1.00  ... -122.233           2720        8062
# 3  604000.0         4       3.00  ... -122.393           1360        5000
# 4  510000.0         3       2.00  ... -122.045           1800        7503
#
# [5 rows x 18 columns]

# %%
del df['long']

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  ...  zipcode  sqft_living15  sqft_lot15
# 0  221900.0         3       1.00  ...    98178           1340        5650
# 1  538000.0         3       2.25  ...    98125           1690        7639
# 2  180000.0         2       1.00  ...    98028           2720        8062
# 3  604000.0         4       3.00  ...    98136           1360        5000
# 4  510000.0         3       2.00  ...    98074           1800        7503
#
# [5 rows x 17 columns]

# %%
del df['view']

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  ...  zipcode  sqft_living15  sqft_lot15
# 0  221900.0         3       1.00  ...    98178           1340        5650
# 1  538000.0         3       2.25  ...    98125           1690        7639
# 2  180000.0         2       1.00  ...    98028           2720        8062
# 3  604000.0         4       3.00  ...    98136           1360        5000
# 4  510000.0         3       2.00  ...    98074           1800        7503
#
# [5 rows x 16 columns]

# %%
df.bedrooms.value_counts()
# Out:
# 3     7608
# 4     5257
# 2     2124
# 5     1184
# 6      223
# 1      156
# 7       32
# 0       11
# 8       10
# 9        4
# 10       2
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
df=df[df['bedrooms']!=33]

# %%
df.bedrooms.value_counts()
# Out:
# 3     7608
# 4     5257
# 2     2124
# 5     1184
# 6      223
# 1      156
# 7       32
# 0       11
# 8       10
# 9        4
# 10       2
# 11       1
# Name: bedrooms, dtype: int64

# %%
pd.options.display.float_format = '{:,.0f}'.format
df
# Out:
#         price  bedrooms  bathrooms  ...  zipcode  sqft_living15  sqft_lot15
# 0     221,900         3          1  ...    98178           1340        5650
# 1     538,000         3          2  ...    98125           1690        7639
# 2     180,000         2          1  ...    98028           2720        8062
# 3     604,000         4          3  ...    98136           1360        5000
# 4     510,000         3          2  ...    98074           1800        7503
# ...       ...       ...        ...  ...      ...            ...         ...
# 16608 245,000         2          1  ...    98144           1220        1740
# 16609 275,000         4          2  ...    98055           1450        8768
# 16610 270,000         3          2  ...    98023           1570        7227
# 16611 767,250         4          3  ...    98115           2170        4080
# 16612 229,000         3          2  ...    98166           1190        9900
#
# [16612 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16612 entries, 0 to 16612
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          16612 non-null  float64
#  1   bedrooms       16612 non-null  int64
#  2   bathrooms      16612 non-null  float64
#  3   sqft_living    16612 non-null  int64
#  4   sqft_lot       16612 non-null  int64
#  5   floors         16612 non-null  float64
#  6   waterfront     16612 non-null  int64
#  7   condition      16612 non-null  int64
#  8   grade          16612 non-null  int64
#  9   sqft_above     16612 non-null  int64
#  10  sqft_basement  16612 non-null  int64
#  11  yr_built       16612 non-null  int64
#  12  yr_renovated   16612 non-null  int64
#  13  zipcode        16612 non-null  int64
#  14  sqft_living15  16612 non-null  int64
#  15  sqft_lot15     16612 non-null  int64
# dtypes: float64(3), int64(13)
# memory usage: 2.2 MB

# %%
sns.set(style='white')
sns.relplot(x='bedrooms',y='price',hue='bedrooms',alpha=0.7,height=10,data=df)

# %%
sns.set(style='ticks',palette='pastel')
fig, ax = plt.subplots(figsize=(14,10)) 
sns.boxplot(x='bedrooms',y='price',palette=["m", "g"], data=df,ax=ax)

# %%
sns.set(style='ticks',palette='muted')
fig,ax=plt.subplots(figsize=(14,10))
sns.boxplot(x='bathrooms',y='price',palette=["b", "g"],data=df,ax=ax)

# %%
df.corr()
# Out:
#                price  bedrooms  bathrooms  ...  zipcode  sqft_living15  sqft_lot15
# price              1         0          1  ...       -0              1           0
# bedrooms           0         1          1  ...       -0              0           0
# bathrooms          1         1          1  ...       -0              1           0
# sqft_living        1         1          1  ...       -0              1           0
# sqft_lot           0         0          0  ...       -0              0           1
# floors             0         0          1  ...       -0              0           0
# waterfront         0        -0          0  ...        0              0           0
# condition          0         0         -0  ...       -0             -0          -0
# grade              1         0          1  ...       -0              1           0
# sqft_above         1         0          1  ...       -0              1           0
# sqft_basement      0         0          0  ...        0              0           0
# yr_built           0         0          0  ...       -0              0           0
# yr_renovated       0         0          0  ...        0              0           0
# zipcode           -0        -0         -0  ...        1             -0          -0
# sqft_living15      1         0          1  ...       -0              1           0
# sqft_lot15         0         0          0  ...       -0              0           1
#
# [16 rows x 16 columns]

# %%
df1=df[['price', 'bedrooms', 'bathrooms', 'sqft_living',
    'sqft_lot', 'floors', 'waterfront', 'condition', 'grade',
    'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
     'sqft_living15', 'sqft_lot15']]
fig, ax = plt.subplots(figsize=(20,20)) 
sns.heatmap(df.corr(),cmap = 'YlGnBu',annot=True,ax=ax)

# %%
fig,ax=plt.subplots(figsize=(14,10))
df.set_index('grade').groupby('bedrooms')['price'].plot(legend=True)
# Out:
# bedrooms
# 0     AxesSubplot(0.125,0.125;0.775x0.755)
# 1     AxesSubplot(0.125,0.125;0.775x0.755)
# 2     AxesSubplot(0.125,0.125;0.775x0.755)
# 3     AxesSubplot(0.125,0.125;0.775x0.755)
# 4     AxesSubplot(0.125,0.125;0.775x0.755)
# 5     AxesSubplot(0.125,0.125;0.775x0.755)
# 6     AxesSubplot(0.125,0.125;0.775x0.755)
# 7     AxesSubplot(0.125,0.125;0.775x0.755)
# 8     AxesSubplot(0.125,0.125;0.775x0.755)
# 9     AxesSubplot(0.125,0.125;0.775x0.755)
# 10    AxesSubplot(0.125,0.125;0.775x0.755)
# 11    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: price, dtype: object

# %%
fig,ax=plt.subplots(figsize=(12,8))
palette=sns.color_palette('mako_r',6)
ax=sns.lineplot(x='sqft_living',y='price',data=df,hue='bedrooms',palette='mako_r')

# %%
fig,ax=plt.subplots(figsize=(12,8))
palette=sns.color_palette('mako_r',6)
ax=sns.lineplot(x='sqft_lot',y='price',data=df,hue='bedrooms',palette='mako_r')

# %%
df['condition'].value_counts()
# Out:
# 3    10216
# 4     4808
# 5     1424
# 2      141
# 1       23
# Name: condition, dtype: int64

# %%
sns.catplot(x='condition',y='price',data=df)

# %%
fig=plt.figure(figsize=(20,13))
ax=fig.add_subplot(2,2,1,projection='3d')
ax.scatter(df['floors'],df['bedrooms'],df['bathrooms'],c='darkgreen',alpha=0.5)
ax.set(xlabel='\nfloors',ylabel='\nbedrooms',zlabel='\nbathrooms')
ax.set(ylim=[0,12])

ax=fig.add_subplot(2,2,2,projection='3d')
ax.scatter(df['floors'],df['bedrooms'],df['sqft_living'],c='darkgreen',alpha=0.5)
ax.set(xlabel='\nfloors',ylabel='\nbedrooms',zlabel='\nsqft living')
ax.set(ylim=[0,12])

ax=fig.add_subplot(2,2,3,projection='3d')
ax.scatter(df['sqft_living'],df['sqft_lot'],df['bathrooms'],c='darkgreen',alpha=0.5)
ax.set(xlabel='\nsqft living',ylabel='\nsqft lot',zlabel='\nbathrooms')
ax.set(ylim=[0,250000])

ax=fig.add_subplot(2,2,4,projection='3d')
ax.scatter(df['sqft_living'],df['sqft_lot'],df['bedrooms'],c='darkgreen',alpha=0.5)
ax.set(xlabel='\nsqft living',ylabel='\nsqft lot',zlabel='\nbedrooms')
ax.set(ylim=[0,250000])
# Out:
# [(0.0, 250000.0)]

# %%
X=df.drop('price',axis=1)
y=df['price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Linear Regression
reg = LinearRegression()
regmodel = reg.fit(X_train, y_train)

coef = reg.coef_

y_predtrain = regmodel.predict(X_train)

y_predtest = regmodel.predict(X_test)

# %%
RMSEtrain = mean_squared_error(y_train, y_predtrain)**0.5
RMSEtest = mean_squared_error(y_test, y_predtest)**0.5
r2_train = r2_score(y_train, y_predtrain)
r2_test = r2_score(y_test, y_predtest)
print( RMSEtrain)
print ("RMSE for the testing data is: ", RMSEtest)
print ("R^2 value for training data is: ", r2_train)
print ("R^2 value for testing data is: ", r2_test)
# Out:
# 209499.4715488401
# RMSE for the testing data is:  231704.61653279111
# R^2 value for training data is:  0.6580247840398121
# R^2 value for testing data is:  0.6379831896543371

# %%
eval_data = pd.read_csv('https://raw.githubusercontent.com/dphi-official/Datasets/master/kc_house_data/kc_house_new_test_data.csv')

# %%
eval_data.head()
# Out:
#    bedrooms  bathrooms  sqft_living  ...  long  sqft_living15  sqft_lot15
# 0         5          3         5210  ...  -122           2590       10250
# 1         5          2         2800  ...  -122           1760       18282
# 2         4          2         2060  ...  -122           2160       45657
# 3         5          2         2360  ...  -122           1860       19998
# 4         4          2         2370  ...  -122           2370        7378
#
# [5 rows x 18 columns]

# %%
eval_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4999 entries, 0 to 4998
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bedrooms       4999 non-null   int64
#  1   bathrooms      4999 non-null   float64
#  2   sqft_living    4999 non-null   int64
#  3   sqft_lot       4999 non-null   int64
#  4   floors         4999 non-null   float64
#  5   waterfront     4999 non-null   int64
#  6   view           4999 non-null   int64
#  7   condition      4999 non-null   int64
#  8   grade          4999 non-null   int64
#  9   sqft_above     4999 non-null   int64
#  10  sqft_basement  4999 non-null   int64
#  11  yr_built       4999 non-null   int64
#  12  yr_renovated   4999 non-null   int64
#  13  zipcode        4999 non-null   int64
#  14  lat            4999 non-null   float64
#  15  long           4999 non-null   float64
#  16  sqft_living15  4999 non-null   int64
#  17  sqft_lot15     4999 non-null   int64
# dtypes: float64(4), int64(14)
# memory usage: 703.1 KB

# %%
del eval_data['lat']

# %%
del eval_data['view']

# %%
del eval_data['long']

# %%
eval_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4999 entries, 0 to 4998
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bedrooms       4999 non-null   int64
#  1   bathrooms      4999 non-null   float64
#  2   sqft_living    4999 non-null   int64
#  3   sqft_lot       4999 non-null   int64
#  4   floors         4999 non-null   float64
#  5   waterfront     4999 non-null   int64
#  6   condition      4999 non-null   int64
#  7   grade          4999 non-null   int64
#  8   sqft_above     4999 non-null   int64
#  9   sqft_basement  4999 non-null   int64
#  10  yr_built       4999 non-null   int64
#  11  yr_renovated   4999 non-null   int64
#  12  zipcode        4999 non-null   int64
#  13  sqft_living15  4999 non-null   int64
#  14  sqft_lot15     4999 non-null   int64
# dtypes: float64(2), int64(13)
# memory usage: 585.9 KB

# %%
predictions=regmodel.predict(eval_data)

# %%
res = pd.DataFrame(predictions) 
res.index = eval_data.index 
res.columns = ["prediction"]

from google.colab import files
res.to_csv('prediction_results.csv')         
files.download('prediction_results.csv')
